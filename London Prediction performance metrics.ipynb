# %%
import pandas as pd 
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df_preds = pd.read_csv("C:/Users/nicol/OneDrive/Master/Goldsmiths/Thesis/weather-prediction/data/df_with_all_preds.csv")

# %%
df_preds.head()
# Out:
#    Unnamed: 0  temp  dew  humidity  precip  precipprob  precipcover  snow  \
# 0  2023-05-22  15.1  6.9      64.3     0.0         0.0          0.0   0.0
# 1  2023-05-23  14.0  6.1      60.6     0.0         0.0          0.0   0.0
# 2  2023-05-24  15.8  6.7      61.2     0.0         0.0          0.0   0.0
# 3  2023-05-25  15.0  6.7      57.9     0.0         0.0          0.0   0.0
# 4  2023-05-26  14.2  6.9      63.5     0.0         0.0          0.0   0.0
#
#    snowdepth  windgust  ...   preds_gs  sktime_naive  naive_last  \
# 0        0.0      26.1  ...  13.432552     12.189839   12.189839
# 1        0.0      36.4  ...  14.786562     12.189839   12.189839
# 2        0.0      34.7  ...  15.185232     12.189839   12.189839
# 3        0.0      41.5  ...  13.373943     12.189839   12.189839
# 4        0.0      26.1  ...  14.683416     12.189839   12.189839
#
#    preds_autoarima  preds_sarimax  lstm_base  lstm_two_layers  \
# 0        13.984044      15.701231  15.777449        15.368996
# 1        13.895126      15.439488  16.630573        15.308199
# 2        13.759057      16.274314  17.326608        15.238746
# 3        13.725513      16.052129  17.891799        15.167250
# 4        13.632718      14.740708  18.356468        15.097821
#
#    lstm_two_layers_batch_size_1  lstm_features  sarimax_gs
# 0                     13.841642      12.066167    1.085501
# 1                     13.047831      12.066167    1.225803
# 2                     12.342554      12.066167    4.254934
# 3                     11.648980      12.066167    3.296934
# 4                     10.958488      12.066167    0.700043
#
# [5 rows x 45 columns]

# %%
df_preds.columns
# Out:
# Index(['Unnamed: 0', 'temp', 'dew', 'humidity', 'precip', 'precipprob',
#        'precipcover', 'snow', 'snowdepth', 'windgust', 'windspeed', 'winddir',
#        'sealevelpressure', 'cloudcover', 'visibility', 'solarradiation',
#        'solarenergy', 'uvindex', 'severerisk', 'moonphase',
#        'clusters_description', 'year', 'month_1', 'month_2', 'month_3',
#        'month_4', 'month_5', 'month_6', 'month_7', 'month_8', 'month_9',
#        'month_10', 'month_11', 'month_12', 'preds', 'preds_gs', 'sktime_naive',
#        'naive_last', 'preds_autoarima', 'preds_sarimax', 'lstm_base',
#        'lstm_two_layers', 'lstm_two_layers_batch_size_1', 'lstm_features',
#        'sarimax_gs'],
#       dtype='object')

# %%
columns_todrop = ['Unnamed: 0', 'dew', 'humidity', 'precip', 'precipprob',
       'precipcover', 'snow', 'snowdepth', 'windgust', 'windspeed', 'winddir',
       'sealevelpressure', 'cloudcover', 'visibility', 'solarradiation',
       'solarenergy', 'uvindex', 'severerisk', 'moonphase',
       'clusters_description', 'year', 'month_1', 'month_2', 'month_3',
       'month_4', 'month_5', 'month_6', 'month_7', 'month_8', 'month_9',
       'month_10', 'month_11', 'month_12']
df_preds = df_preds.drop(columns_todrop, axis=1)
df_preds.head()
# Out:
#    temp      preds   preds_gs  sktime_naive  naive_last  preds_autoarima  \
# 0  15.1  14.492051  13.432552     12.189839   12.189839        13.984044
# 1  14.0  17.870735  14.786562     12.189839   12.189839        13.895126
# 2  15.8  16.441523  15.185232     12.189839   12.189839        13.759057
# 3  15.0  14.017682  13.373943     12.189839   12.189839        13.725513
# 4  14.2  13.380795  14.683416     12.189839   12.189839        13.632718
#
#    preds_sarimax  lstm_base  lstm_two_layers  lstm_two_layers_batch_size_1  \
# 0      15.701231  15.777449        15.368996                     13.841642
# 1      15.439488  16.630573        15.308199                     13.047831
# 2      16.274314  17.326608        15.238746                     12.342554
# 3      16.052129  17.891799        15.167250                     11.648980
# 4      14.740708  18.356468        15.097821                     10.958488
#
#    lstm_features  sarimax_gs
# 0      12.066167    1.085501
# 1      12.066167    1.225803
# 2      12.066167    4.254934
# 3      12.066167    3.296934
# 4      12.066167    0.700043

# %%
df_preds.columns
# Out:
# Index(['temp', 'preds', 'preds_gs', 'sktime_naive', 'naive_last',
#        'preds_autoarima', 'preds_sarimax', 'lstm_base', 'lstm_two_layers',
#        'lstm_two_layers_batch_size_1', 'lstm_features', 'sarimax_gs'],
#       dtype='object')

# %%
df_preds = df_preds.rename(columns={
   'preds': 'XGBoost baseline London', 
    'preds_gs' : 'XGBoost grid search London', 
    'sktime_naive' : 'Naive Forecaster Baseline London', 
    'naive_last' : 'Naive Forecaster Last Stategy London',
       'preds_autoarima' : 'Auto-ARIMA London',
    'preds_sarimax' : 'SARIMAX baseline London', 
    'lstm_base': 'LSTM baseline London', 
    'lstm_two_layers':'LSTM with two layers London',
       'lstm_two_layers_batch_size_1':'LSTM with layers and batch size London',
    'lstm_features':'LSTM with features London', 
    'sarimax_gs':'SARIMAX grid search London'
})
df_preds.head()
# Out:
#    temp  XGBoost baseline London  XGBoost grid search London  \
# 0  15.1                14.492051                   13.432552
# 1  14.0                17.870735                   14.786562
# 2  15.8                16.441523                   15.185232
# 3  15.0                14.017682                   13.373943
# 4  14.2                13.380795                   14.683416
#
#    Naive Forecaster Baseline London  Naive Forecaster Last Stategy London  \
# 0                         12.189839                             12.189839
# 1                         12.189839                             12.189839
# 2                         12.189839                             12.189839
# 3                         12.189839                             12.189839
# 4                         12.189839                             12.189839
#
#    Auto-ARIMA London  SARIMAX baseline London  LSTM baseline London  \
# 0          13.984044                15.701231             15.777449
# 1          13.895126                15.439488             16.630573
# 2          13.759057                16.274314             17.326608
# 3          13.725513                16.052129             17.891799
# 4          13.632718                14.740708             18.356468
#
#    LSTM with two layers London  LSTM with layers and batch size London  \
# 0                    15.368996                               13.841642
# 1                    15.308199                               13.047831
# 2                    15.238746                               12.342554
# 3                    15.167250                               11.648980
# 4                    15.097821                               10.958488
#
#    LSTM with features London  SARIMAX grid search London
# 0                  12.066167                    1.085501
# 1                  12.066167                    1.225803
# 2                  12.066167                    4.254934
# 3                  12.066167                    3.296934
# 4                  12.066167                    0.700043

# %%
def calculate_metrics(actual, predicted):
    mae = mean_absolute_error(actual, predicted)
    mse = mean_squared_error(actual, predicted)
    rmse = np.sqrt(mse)
    r2 = r2_score(actual, predicted)
   #calculate MAPE
    mask = actual != 0  
    mape = np.mean(((actual[mask] - predicted[mask]) / actual[mask])) * 100
    
    return mae, mse, rmse, r2, mape

metrics_list = []

# calculate metrics for each model 
for col in df_preds.columns:
    if col != 'temp':
        mae, mse, rmse, r2, mape = calculate_metrics(df_preds['temp'], df_preds[col])
        metrics_list.append({
            'Model': col,
            'MAE': mae,
            'MSE': mse,
            'RMSE': rmse,
            'R2': r2,
            'MAPE': mape
        })

metrics_df = pd.DataFrame(metrics_list)

# %%
metrics_by_mae = metrics_df.sort_values(by='MAE', ascending=True)

# %%
metrics_by_mae
# Out:
#                                      Model        MAE          MSE       RMSE  \
# 1               XGBoost grid search London   2.103032     7.130397   2.670280
# 0                  XGBoost baseline London   2.386807     8.827414   2.971096
# 7              LSTM with two layers London   4.194984    27.362728   5.230939
# 2         Naive Forecaster Baseline London   4.421406    28.217105   5.311978
# 3     Naive Forecaster Last Stategy London   4.421406    28.217105   5.311978
# 9                LSTM with features London   4.429446    28.432498   5.332213
# 4                        Auto-ARIMA London   4.440994    27.790480   5.271668
# 8   LSTM with layers and batch size London   6.326612    59.461907   7.711155
# 10              SARIMAX grid search London  10.032825   126.466961  11.245753
# 5                  SARIMAX baseline London  28.006129  1045.717374  32.337554
# 6                     LSTM baseline London  42.981212  2096.584465  45.788475
#
#            R2        MAPE
# 1    0.741301  -12.492555
# 0    0.679731   -7.501623
# 7    0.007249  -12.841021
# 2   -0.023749  -44.973731
# 3   -0.023749  -44.973731
# 9   -0.031564  -43.502910
# 4   -0.008271  -60.464816
# 8   -1.157347   13.045202
# 10  -3.588367   22.349657
# 5  -36.939833 -431.363625
# 6  -75.066503 -606.598101

# %%
#sorted by MAPE

# %%
metrics_by_mape = metrics_df.sort_values(by='MAPE')

# %%
metrics_by_mape
# Out:
#                                      Model        MAE          MSE       RMSE  \
# 6                     LSTM baseline London  42.981212  2096.584465  45.788475
# 5                  SARIMAX baseline London  28.006129  1045.717374  32.337554
# 4                        Auto-ARIMA London   4.440994    27.790480   5.271668
# 2         Naive Forecaster Baseline London   4.421406    28.217105   5.311978
# 3     Naive Forecaster Last Stategy London   4.421406    28.217105   5.311978
# 9                LSTM with features London   4.429446    28.432498   5.332213
# 7              LSTM with two layers London   4.194984    27.362728   5.230939
# 1               XGBoost grid search London   2.103032     7.130397   2.670280
# 0                  XGBoost baseline London   2.386807     8.827414   2.971096
# 8   LSTM with layers and batch size London   6.326612    59.461907   7.711155
# 10              SARIMAX grid search London  10.032825   126.466961  11.245753
#
#            R2        MAPE
# 6  -75.066503 -606.598101
# 5  -36.939833 -431.363625
# 4   -0.008271  -60.464816
# 2   -0.023749  -44.973731
# 3   -0.023749  -44.973731
# 9   -0.031564  -43.502910
# 7    0.007249  -12.841021
# 1    0.741301  -12.492555
# 0    0.679731   -7.501623
# 8   -1.157347   13.045202
# 10  -3.588367   22.349657

# %%
# mae for xgb with gs and lstm with feature mape
